# %% [markdown]
# <a href="https://colab.research.google.com/github/TobiasRoth/Publication_Tagfalterindex/blob/main/R/TFI_BDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Skript laufen lassen

# %%
# Install Packages
# install.packages('rstan', dependencies = TRUE)
library(rstan)
# Out:
# Error in library(rstan): there is no package called ‘rstan’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
library(rstan)
# Out:
# Error in library(rstan): there is no package called ‘rstan’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
list.files()
# Out:
# [1] "Data"        "sample_data"
